# %%
from stimulus.data import data_handlers
from stimulus.data import loaders
from stimulus.data import handlertorch
import download_dream_to_stimulus_format
import os

# %%
# check if the data is already downloaded
if not os.path.exists(download_dream_to_stimulus_format.OUTPUT_FILE):
    download_dream_to_stimulus_format.download_dream_to_stimulus_format()
